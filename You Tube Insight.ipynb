# %%
#IMPORTING NECESSARY LIBRARIES
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("You Tube Statistics 2023.csv",encoding = "latin")

# %%
df.head()
# Out:
#    rank                    Youtuber  subscribers   video views  \
# 0     1                    T-Series    245000000  2.280000e+11
# 1     2              YouTube Movies    170000000  0.000000e+00
# 2     3                     MrBeast    166000000  2.836884e+10
# 3     4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4     5                   SET India    159000000  1.480000e+11
#
#            category                       Title  uploads        Country  \
# 0             Music                    T-Series    20082          India
# 1  Film & Animation               youtubemovies        1  United States
# 2     Entertainment                     MrBeast      741  United States
# 3         Education  Cocomelon - Nursery Rhymes      966  United States
# 4             Shows                   SET India   116536          India
#
#   Abbreviation   channel_type  ...  subscribers_for_last_30_days  \
# 0           IN          Music  ...                     2000000.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 995 entries, 0 to 994
# Data columns (total 28 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   rank                                     995 non-null    int64
#  1   Youtuber                                 995 non-null    object
#  2   subscribers                              995 non-null    int64
#  3   video views                              995 non-null    float64
#  4   category                                 949 non-null    object
#  5   Title                                    995 non-null    object
#  6   uploads                                  995 non-null    int64
#  7   Country                                  873 non-null    object
#  8   Abbreviation                             873 non-null    object
#  9   channel_type                             965 non-null    object
# ...

# %%
df.describe()
# Out:
#             rank   subscribers   video views        uploads  video_views_rank  \
# count  995.00000  9.950000e+02  9.950000e+02     995.000000      9.940000e+02
# mean   498.00000  2.298241e+07  1.103954e+10    9187.125628      5.542489e+05
# std    287.37606  1.752611e+07  1.411084e+10   34151.352254      1.362782e+06
# min      1.00000  1.230000e+07  0.000000e+00       0.000000      1.000000e+00
# 25%    249.50000  1.450000e+07  4.288145e+09     194.500000      3.230000e+02
# 50%    498.00000  1.770000e+07  7.760820e+09     729.000000      9.155000e+02
# 75%    746.50000  2.460000e+07  1.355470e+10    2667.500000      3.584500e+03
# max    995.00000  2.450000e+08  2.280000e+11  301308.000000      4.057944e+06
#
#        country_rank  channel_type_rank  video_views_for_the_last_30_days  \
# count    879.000000         962.000000                      9.390000e+02
# mean     386.053470         745.719335                      1.756103e+08
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# rank                                         0
# Youtuber                                     0
# subscribers                                  0
# video views                                  0
# category                                    46
# Title                                        0
# uploads                                      0
# Country                                    122
# Abbreviation                               122
# channel_type                                30
# video_views_rank                             1
# country_rank                               116
# channel_type_rank                           33
# video_views_for_the_last_30_days            56
# lowest_monthly_earnings                      0
# highest_monthly_earnings                     0
# lowest_yearly_earnings                       0
# highest_yearly_earnings                      0
# subscribers_for_last_30_days               337
# created_year                                 5
# ...

# %%
df.shape
# Out:
# (995, 28)

# %% [markdown]
# # EDA

# %%
df.columns
# Out:
# Index(['rank', 'Youtuber', 'subscribers', 'video views', 'category', 'Title',
#        'uploads', 'Country', 'Abbreviation', 'channel_type',
#        'video_views_rank', 'country_rank', 'channel_type_rank',
#        'video_views_for_the_last_30_days', 'lowest_monthly_earnings',
#        'highest_monthly_earnings', 'lowest_yearly_earnings',
#        'highest_yearly_earnings', 'subscribers_for_last_30_days',
#        'created_year', 'created_month', 'created_date',
#        'Gross tertiary education enrollment (%)', 'Population',
#        'Unemployment rate', 'Urban_population', 'Latitude', 'Longitude'],
#       dtype='object')

# %% [markdown]
# ## 1) WHICH IS THE MOST CATEGORY IN YOUTUBE ?

# %%
df['category'].value_counts()
# Out:
# category
# Entertainment            241
# Music                    202
# People & Blogs           132
# Gaming                    94
# Comedy                    69
# Film & Animation          46
# Education                 45
# Howto & Style             40
# News & Politics           26
# Science & Technology      17
# Shows                     13
# Sports                    11
# Pets & Animals             4
# Trailers                   2
# Nonprofits & Activism      2
# Movies                     2
# Autos & Vehicles           2
# Travel & Events            1
# Name: count, dtype: int64

# %%
plt.figure(figsize = (10,5))
sns.countplot(y= 'category',data = df,order = df['category'].value_counts().head(20).index)
plt.xlabel("count of category")
plt.ylabel("category")
plt.title("category wise count")
plt.show()

# %% [markdown]
#  ### The dominant categories on YouTube are entertainment and music, attracting the largest audience engagement and viewership.

# %% [markdown]
# # 2) WHICH IS THE MOST COUNTRY ON YOUTUBE ?

# %%
df['Country'].unique()
# Out:
# array(['India', 'United States', nan, 'Japan', 'Russia', 'South Korea',
#        'United Kingdom', 'Canada', 'Brazil', 'Argentina', 'Chile', 'Cuba',
#        'El Salvador', 'Pakistan', 'Philippines', 'Thailand', 'Colombia',
#        'Barbados', 'Mexico', 'United Arab Emirates', 'Spain',
#        'Saudi Arabia', 'Indonesia', 'Turkey', 'Venezuela', 'Kuwait',
#        'Jordan', 'Netherlands', 'Singapore', 'Australia', 'Italy',
#        'Germany', 'France', 'Sweden', 'Afghanistan', 'Ukraine', 'Latvia',
#        'Switzerland', 'Vietnam', 'Malaysia', 'China', 'Iraq', 'Egypt',
#        'Andorra', 'Ecuador', 'Morocco', 'Peru', 'Bangladesh', 'Finland',
#        'Samoa'], dtype=object)

# %%
# df['Country'].value_counts()
plt.figure(figsize = (10,5))
sns.countplot(y = 'Country',data = df,order = df['Country'].value_counts().head(20).index,palette='muted')
plt.xlabel('Number of Channels')
plt.ylabel('Country')
plt.title('Distribution of Channels by Country')
plt.show()

# %% [markdown]
# ### "The analysis indicated that the United States and India were the countries with the highest YouTube user base

# %%
plt.figure(figsize = (10,5))
sns.countplot(y = 'Country',data = df,order = df['Country'].value_counts().head(20).index,palette='muted')
plt.xlabel('Number of Channels')
plt.ylabel('Country')
plt.title('Distribution of Channels by Country')
plt.show()

# %% [markdown]
# ### "The analysis indicated that the United States and India were the countries with the highest YouTube user base."

# %% [markdown]
# # 3) WHICH IS THE MOST CHANNEL TYPE ON YOUTUBE ?

# %%
channel_type_counts = df['channel_type'].value_counts()
channel_type_counts
# Out:
# channel_type
# Entertainment    304
# Music            216
# People           101
# Games             98
# Comedy            51
# Education         49
# Film              42
# Howto             36
# News              30
# Tech              17
# Sports            13
# Autos              3
# Animals            3
# Nonprofit          2
# Name: count, dtype: int64

# %%
channel_type_counts.head(10).plot(kind = "pie",autopct = "%1.1f%%")
plt.title("channel type distribution")
plt.show()

# %% [markdown]
# ### "The analysis revealed that the most prevalent channel type on YouTube was Entertainment, constituting 32.2% of the total, followed by Music at 22.9%."

# %% [markdown]
# # 4) which year did YouTube channel creations experience the most significant increase?

# %%
df['created_year'].value_counts()
# Out:
# created_year
# 2014.0    98
# 2006.0    91
# 2011.0    82
# 2016.0    77
# 2013.0    76
# 2015.0    73
# 2017.0    68
# 2012.0    68
# 2009.0    52
# 2007.0    49
# 2010.0    48
# 2018.0    46
# 2008.0    46
# 2019.0    33
# 2020.0    30
# 2005.0    24
# 2021.0    23
# 2022.0     5
# 1970.0     1
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 6))
plt.hist(df['created_year'], bins=10, color='skyblue', edgecolor='black', alpha=0.7)
plt.title('Distribution of Created Year')
plt.xlabel('Year')
plt.ylabel('Frequency')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# ### "The analysis revealed a significant increase in YouTube channel creations between 2014 and 2018."

# %% [markdown]
# # BI-VARIENT

# %%
df.columns
# Out:
# Index(['rank', 'Youtuber', 'subscribers', 'video views', 'category', 'Title',
#        'uploads', 'Country', 'Abbreviation', 'channel_type',
#        'video_views_rank', 'country_rank', 'channel_type_rank',
#        'video_views_for_the_last_30_days', 'lowest_monthly_earnings',
#        'highest_monthly_earnings', 'lowest_yearly_earnings',
#        'highest_yearly_earnings', 'subscribers_for_last_30_days',
#        'created_year', 'created_month', 'created_date',
#        'Gross tertiary education enrollment (%)', 'Population',
#        'Unemployment rate', 'Urban_population', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
df.head()
# Out:
#    rank                    Youtuber  subscribers   video views  \
# 0     1                    T-Series    245000000  2.280000e+11
# 1     2              YouTube Movies    170000000  0.000000e+00
# 2     3                     MrBeast    166000000  2.836884e+10
# 3     4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4     5                   SET India    159000000  1.480000e+11
#
#            category                       Title  uploads        Country  \
# 0             Music                    T-Series    20082          India
# 1  Film & Animation               youtubemovies        1  United States
# 2     Entertainment                     MrBeast      741  United States
# 3         Education  Cocomelon - Nursery Rhymes      966  United States
# 4             Shows                   SET India   116536          India
#
#   Abbreviation   channel_type  ...  subscribers_for_last_30_days  \
# 0           IN          Music  ...                     2000000.0
# ...

# %% [markdown]
# # 5) Which YouTuber has the highest number of subscribers ?

# %%
top_10_youtubers = df.nlargest(10, 'subscribers')

plt.figure(figsize=(10, 5))
sns.barplot(x='subscribers', y='Youtuber', data=top_10_youtubers, palette='muted')
plt.xlabel('Subscribers')
plt.ylabel('YouTuber')
plt.title('Top 10 YouTubers with the Most Subscribers')
plt.show()

# %% [markdown]
# ### "T-Series, YouTube Movies, and MrBeast stand out as the leading YouTube channels, boasting the highest number of subscribers among all channels in the dataset."

# %% [markdown]
# # 6) Which YouTuber has the highest number of views?

# %%
top_10_youtubers = df.nlargest(10,'video views')

plt.figure(figsize = (10,5))
sns.barplot(x = 'video views',y = "Youtuber",data = top_10_youtubers,palette='dark')
plt.xlabel('video views')
plt.ylabel('Youtuber')
plt.title('Top 10 youtuber with most video views')
plt.show()

# %% [markdown]
# ### T-Series, Cocomelon - Nursery Rhymes, and SET India emerge as the top three channels with the highest number of views, showcasing their significant impact and popularity on the platform."

# %% [markdown]
# # 7) Which YouTuber has uploaded the most number of videos in the dataset ?

# %%
top_20_youtuber = df.nlargest(20,'uploads')

plt.figure(figsize = (10,5))
sns.barplot(x = "Youtuber",y = "uploads",data = top_20_youtuber,palette='muted')
plt.xlabel('Youtuber')
plt.ylabel('Video Upload')
plt.xticks(rotation = 90)
plt.title('Top 10 youtuber with most upload video')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### News channels significantly outnumber other categories in terms of video uploads.
#
# ### The frequency of uploads by news channels highlights their commitment to providing up-to-date information and engaging with their audience.

# %% [markdown]
# # 8) Which YouTuber is associated with the most number of countries in the dataset ?

# %%
channel_count_by_country = df.groupby('Country')['Youtuber'].nunique().reset_index().sort_values(by='Youtuber', ascending=False)

# Plot the distribution of YouTube channels by country
plt.figure(figsize=(10, 5))
sns.barplot(x='Country', y='Youtuber', data=channel_count_by_country, palette='viridis')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.title('Number of YouTube Channels by Country')
plt.xlabel('Country')
plt.ylabel('Number of YouTube Channels')
plt.show()

# %% [markdown]
# ### United States and India are the most number of Youtube Channel By Country

# %% [markdown]
# # 9) Which YouTuber has the highest monthly/year earnings in the dataset ?

# %%
top_20_highest_earners = df.nlargest(20, 'highest_monthly_earnings')

plt.figure(figsize=(10, 8))
sns.barplot(x='highest_monthly_earnings', y='Youtuber', data=top_20_highest_earners, palette='Blues_d')
plt.xlabel('Highest Monthly Earnings')
plt.ylabel('YouTuber')
plt.title('Top 20 YouTubers with Highest Monthly Earnings')
plt.show()

# %%
top_20_highest_earners = df.nlargest(20, 'highest_yearly_earnings')

plt.figure(figsize=(10, 8))
sns.barplot(x='highest_yearly_earnings', y='Youtuber', data=top_20_highest_earners, palette='Blues_d')
plt.xlabel('Highest Monthly Earnings')
plt.ylabel('YouTuber')
plt.title('Top 20 YouTubers with Highest year Earnings')
plt.show()

# %% [markdown]
# ### KimPro, DaFuqBoom, T-Series, KL Bro Biji Rithvik, and Cocomelon - Nursery Rhymes emerge as the top five channels with the highest monthly and yearly earnings.

# %% [markdown]
# # 10) Is there a correlation between the number of subscribers ?

# %%
# Scatter plot 1: Subscribers vs. Number of Uploads
plt.figure(figsize=(10, 6))
plt.scatter(df['subscribers'], df['uploads'], alpha=0.5)
plt.title('Subscribers vs. Number of Uploads')
plt.xlabel('Subscribers')
plt.ylabel('Number of Uploads')
plt.grid(True)
plt.show()


# Scatter plot 2: Subscribers vs. Unemployment Rate
plt.figure(figsize=(10, 6))
plt.scatter(df['subscribers'], df['Unemployment rate'], alpha=0.5)
plt.title('Subscribers vs. Unemployment Rate')
plt.xlabel('Subscribers')
plt.ylabel('Unemployment Rate')
plt.grid(True)
plt.show()

# %% [markdown]
# # 11) Which categories of YouTube channels appear to be the most popular based on their subscriber counts ?

# %%
category_subscribers = df.groupby("category")["subscribers"].sum().reset_index()
category_subscribers_sorted = category_subscribers.sort_values(by = "subscribers",ascending = False)
category_subscribers_sorted
# Out:
#                  category  subscribers
# 8                   Music   5195000000
# 3           Entertainment   5158200000
# 11         People & Blogs   2779400000
# 5                  Gaming   1960100000
# 1                  Comedy   1388500000
# 4        Film & Animation   1314900000
# 2               Education   1194400000
# 6           Howto & Style    775600000
# 14                  Shows    541000000
# 9         News & Politics    536400000
# 13   Science & Technology    316500000
# 15                 Sports    298200000
# 16               Trailers     78000000
# 12         Pets & Animals     72400000
# 10  Nonprofits & Activism     55500000
# 7                  Movies     51300000
# 0        Autos & Vehicles     35700000
# 17        Travel & Events     12500000

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='subscribers', y='category', data=category_subscribers_sorted, palette='viridis')
plt.xlabel('Subscribers')
plt.ylabel('Category')
plt.title('Total Subscribers by Category')
plt.show()

# %% [markdown]
# ### Music,Entertainment are this category has most number of subscribers

# %% [markdown]
# # 12) Which category are most video views ?

# %%
df['category'] = df['category'].astype(str)

category = df['category']
video_views = df['video views']

# Plotting
plt.figure(figsize=(10, 6))
plt.scatter(category, video_views, alpha=0.5)
plt.title('Scatter Plot of Category vs Video Views')
plt.xlabel('Category')
plt.ylabel('Video Views')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Music Category more number of views compare than other category

# %% [markdown]
# # Which countries are among the top 4 in terms of total video views ?

# %%
country_views = df.groupby('Country')['video views'].sum().sort_values(ascending=False)

# Select top 4 countries
top_countries = country_views.head(4)

# Plot total video views for top 4 countries
plt.figure(figsize=(10, 6))
top_countries.plot(kind='bar', color='skyblue')
plt.title('Total Video Views by Top 4 Countries')
plt.xlabel('Country')
plt.ylabel('Total Video Views')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### United States,India,Btazil nd United Kingdom are the top 4 country has highest number of video views

# %% [markdown]
# # 14) Which category has the highest monthly earnings and highest yearly earning ?

# %%
highest_monthly_earning_by_category = df.groupby('category')['highest_monthly_earnings'].max()


print("Highest monthly earnings by category:")
print(highest_monthly_earning_by_category)
# Out:
# Highest monthly earnings by category:
# category
# Autos & Vehicles          1400000.0
# Comedy                    5000000.0
# Education                 7900000.0
# Entertainment             8100000.0
# Film & Animation          9200000.0
# Gaming                    4300000.0
# Howto & Style             2000000.0
# Movies                     909400.0
# Music                     9000000.0
# News & Politics           1800000.0
# Nonprofits & Activism      598200.0
# People & Blogs            5500000.0
# Pets & Animals            3000000.0
# Science & Technology       670800.0
# Shows                     7300000.0
# Sports                    2900000.0
# Trailers                   723800.0
# Travel & Events            124000.0
# nan                      13600000.0
# Name: highest_monthly_earnings, dtype: float64

# %%
highest_monthly_earning_by_category = df.groupby('category')['highest_monthly_earnings'].max().reset_index()
highest_yearly_earning_by_category = df.groupby('category')['highest_yearly_earnings'].max().reset_index()

# Plot the highest monthly earnings by category
plt.figure(figsize=(10, 6))
sns.barplot(x='category', y='highest_monthly_earnings', data=highest_monthly_earning_by_category, palette='pastel')
plt.xlabel('Category')
plt.ylabel('Highest Monthly Earnings')
plt.title('Highest Monthly Earnings by Category')
plt.xticks(rotation=90)
plt.show()

# Plot the highest yearly earnings by category
plt.figure(figsize=(10, 6))
sns.barplot(x='category', y='highest_yearly_earnings', data=highest_yearly_earning_by_category, palette='pastel')
plt.xlabel('Category')
plt.ylabel('Highest Yearly Earnings')
plt.title('Highest Yearly Earnings by Category')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Music, films and animation, and entertainment emerge as the highest-earning categories both on a monthly and yearly basis, indicating their profitability and appeal to advertisers and viewers alike.

# %% [markdown]
# ## 15) Which Country has highest unemployemment rate ?

# %%
avg_unemployment_rate_by_country = df.groupby('Country')['Unemployment rate'].mean().reset_index()
# Sort the data based on the unemployment rate
avg_unemployment_rate_by_country = avg_unemployment_rate_by_country.sort_values(by='Unemployment rate', ascending=False)
print(avg_unemployment_rate_by_country)
# Out:
#                  Country  Unemployment rate
# 23                Jordan              14.72
# 46         United States              14.70
# 38                 Spain              13.96
# 42                Turkey              13.49
# 20                  Iraq              12.82
# 6                 Brazil              12.08
# 0            Afghanistan              11.12
# 13                 Egypt              10.76
# 5               Barbados              10.33
# 21                 Italy               9.89
# 2              Argentina               9.79
# 10              Colombia               9.71
# 28               Morocco               9.02
# 43               Ukraine               8.88
# 47             Venezuela               8.80
# 16                France               8.43
# 34                 Samoa               8.36
# 8                  Chile               7.09
# 15               Finland               6.59
# 25                Latvia               6.52
# ...

# %%
top_10_countries = avg_unemployment_rate_by_country.nlargest(10, 'Unemployment rate')
# Plotting
plt.figure(figsize=(10, 8))
sns.barplot(x='Unemployment rate', y='Country', data=top_10_countries, palette='muted')
plt.xlabel('Unemployment Rate by Country')
plt.ylabel('Country')
plt.title('Top 10 Countries with Highest Average Unemployment Rates')
plt.show()

# %% [markdown]
# ### Jordan holds the unfortunate distinction of having the highest unemployment rate among the countries analyzed in our dataset.

# %% [markdown]
# # 17) How do various metrics or activity correlate, providing insights into their interplay and potential impact on YouTube channel performance ?

# %%
# Update relevant variables list to exclude non-numeric columns
relevant_variables = ['video views', 'subscribers', 'Population', 'Unemployment rate', 'Urban_population',
                      'subscribers_for_last_30_days']

# Subset the DataFrame to include only the relevant variables
relevant_df = df[relevant_variables]

# Calculate the correlation matrix
correlation_matrix = relevant_df.corr()

# Plot the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Heatmap of Relevant Variables')
plt.show()

# %% [markdown]
# ### There exists a strong positive correlation between subscriber count and video views, as evidenced by the histogram plot, suggesting that channels with higher subscriber counts tend to garner more views.

# %% [markdown]
# ## 18) Which category of YouTube channels tends to have the highest average number of subscribers across different countries

# %%
df.groupby(['category','Country'])['subscribers'].sum().unstack().plot(kind = "bar",stacked = True)
plt.title("Subscribers Breakdown by Category and Country")
plt.xlabel("Caegory")
plt.ylabel("Total Subscribers")
plt.legend(title = "Country", bbox_to_anchor = (1.05, 1), loc = "upper left")
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# ## The entertainment and music categories witness domination primarily from the USA and India, underscoring the influence and contribution of these two countries to these content genres.

# %% [markdown]
# ## 19) What is the range of video views among YouTube channels across different countries, and are there any channels that stand out with exceptionally high or low view counts?

# %%
subset_df = df[['Country', 'video views', 'category']]

# Create the plot
plt.figure(figsize=(12, 8))
sns.scatterplot(data=subset_df, x='Country', y='video views', hue='category')
plt.title('Country vs. Video Views vs. Category')
plt.xlabel('Country')
plt.ylabel('Video Views')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.legend(title='Category', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### India, USA, and Japan stand out as major influencers on YouTube, featuring prominently across a variety of content categories, demonstrating their global impact

# %% [markdown]
# ## 20) How does the trend of video views over the years relate to the distribution of video views across different years ?

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, sharey=False, figsize=(30,10))
sns.lineplot(data=df, x="created_year", y="video views", ax=ax1)
sns.histplot(df["created_year"], ax=ax2, bins=15)
ax1.set(xlabel="Year", ylabel="Video Views",title= "total Video Views per channels created in the same Year")
ax2.set(xlabel="Year", ylabel="# Channels",title= "Quantity of channels created per year")
plt.show()

# %% [markdown]
# # 21) Which country experienced the highest growth in highest monthly earnings over the observed years

# %%
# Aggregate the data by country and created year, taking the sum of highest yearly earnings
agg_df = df.groupby(['Country', 'created_year'])['highest_yearly_earnings'].sum().reset_index()

# Plot the line plot
plt.figure(figsize=(12, 8))
sns.lineplot(data=agg_df, x='created_year', y='highest_yearly_earnings', hue='Country', marker='o')
plt.title('Highest Yearly Earning by Created Year and Country')
plt.xlabel('Created Year')
plt.ylabel('Highest Yearly Earning')
plt.xticks(rotation=45)
plt.legend(title='Country', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## india and united state this country are top highest monthly and highest yearly earning country in youtube

# %% [markdown]
# # 22) Which category shows the most significant growth in subscribers over the observed years?

# %%
agg_df = df.groupby(['created_year', 'category'])['subscribers'].sum().reset_index()

# Plot the area plot
plt.figure(figsize=(12, 8))
sns.lineplot(x='created_year', y='subscribers', hue='category', data=agg_df, marker='o', estimator=None)
plt.fill_between(agg_df['created_year'], agg_df['subscribers'], color='skyblue', alpha=0.3)
plt.title('Subscriber Growth Over Time by Category')
plt.xlabel('Year')
plt.ylabel('Total Subscribers')
plt.legend(title='Category', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Channels centered around music and comedy consistently attract more subscribers over time, indicating the enduring popularity and appeal of these genres among YouTube audiences.

# %% [markdown]
# # CONCLUSION

# %% [markdown]
# ###  1) The dominant categories on YouTube are entertainment and music, attracting the largest audience engagement and viewership.
# ### 2) The USA stands out as the leading country in terms of the number of YouTube channels, indicating its significant presence and influence on the platform.
# ### 3) Entertainment, music, and people-centric content comprise the majority of YouTube videos in the dataset, with entertainment leading at 32.2%, followed by music at 22.9%, and people-focused content at 10.7%.
# ###  4) Between 2014 and 2018, there was a notable surge in the creation of YouTube channels, suggesting a period of rapid growth and expansion on the platform.
# ### 5)  T-Series, YouTube Movies, and MrBeast emerge as the top three channels with the highest number of subscribers, reflecting their substantial popularity and widespread appeal among YouTube users.
# ### 6) T-Series, Cocomelon - Nursery Rhymes, and SET India stand out as the top three channels with the highest number of views, underscoring their significant influence and resonance with the YouTube audience.
#
# ### 7) News channels exhibit a notably high frequency of video uploads compared to other categories, underscoring their dedication to delivering timely information and engaging with their viewers.
#
# ### 8) The USA and India are the primary contributors to the YouTube ecosystem in our dataset, demonstrating their prominence as sources of content creation and viewership.
#
# ### 9)T-Series, YouTube Movies, and MrBeast emerge as the top three channels with the highest number of subscribers, reflecting their substantial popularity and widespread appeal among YouTube users.
#
# ### 10)KimPro, DaFuqBoom, T-Series, KL Bro Biji Rithvik, and Cocomelon - Nursery Rhymes emerge as the top five channels with the highest monthly and yearly earnings, indicating their success in monetizing their content and engaging with their audience effectively.

# %% [markdown]
# ### 11)Music, films and animation, and entertainment emerge as the highest-earning categories both on a monthly and yearly basis, indicating their profitability and appeal to advertisers and viewers alike.
#
# ### 12)Jordan holds the unfortunate distinction of having the highest unemployment rate among the countries analyzed in our dataset, standing at 14.72%.
#
# ### 13)India leads in terms of total video views, followed by the United States and the United Kingdom, signifying its significant viewership and engagement on the platform.
#
# ### 14)There exists a strong positive correlation between subscriber count and video views, as evidenced by the histogram plot, suggesting that channels with higher subscriber counts tend to garner more views.
#
# ### 15)The entertainment and music categories witness domination primarily from the USA and India, underscoring the influence and contribution of these two countries to these content genres.
#
# ### 16)India, USA, and Japan stand out as major influencers on YouTube, featuring prominently across a variety of content categories, demonstrating their global impact
#
# ### 17)Channels centered around music and comedy consistently attract more subscribers over time, indicating the enduring popularity and appeal of these genres among YouTube audiences.
